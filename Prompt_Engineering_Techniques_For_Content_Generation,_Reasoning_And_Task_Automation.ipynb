# %%
prompt = input("Enter your topic: ")

print("\nGenerated Content:")
print("Write a short and clear explanation about", prompt)

print("\nReasoning:")
print("Analyze the topic and provide the important points.")

print("\nTask Automation:")
print("Task completed successfully for:", prompt)
# Out:
# Enter your topic: Artificial Intelligence
#
# Generated Content:
# Write a short and clear explanation about Artificial Intelligence
#
# Reasoning:
# Analyze the topic and provide the important points.
#
# Task Automation:
# Task completed successfully for: Artificial Intelligence
