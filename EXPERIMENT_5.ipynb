# %% [markdown]
# <a href="https://colab.research.google.com/github/Elam2006/Gen-AI/blob/main/EXPERIMENT_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers torch

from transformers import pipeline

sentiment = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)

texts = [
    "I really enjoyed this course.",
    "The product is excellent and easy t
    o use.",
    "I am disappointed with the service."
]

print("===== SENTIMENT ANALYSIS =====")

for text in texts:

    result = sentiment(text)

    print("\nText:", text)
    print("Sentiment:", result[0]["label"])
    print("Confidence:", round(result[0]["score"], 4))
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors: reconstructing file:   0%|          |  0.00B /  268MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# ===== SENTIMENT ANALYSIS =====
#
# Text: I really enjoyed this course.
# Sentiment: POSITIVE
# Confidence: 0.9999
#
# Text: The product is excellent and easy to use.
# Sentiment: POSITIVE
# Confidence: 0.9999
#
# Text: I am disappointed with the service.
# Sentiment: NEGATIVE
# Confidence: 0.9998
